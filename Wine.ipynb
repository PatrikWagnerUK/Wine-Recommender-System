# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel, sigmoid_kernel

# %% [markdown]
# # Building a Wine Recommendation System
#
# Creating a content-based recommendation system through using NLP modelinng on sommellier reviews.

# %%
df = pd.read_csv('../../Data/wine_data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150930 entries, 0 to 150929
# Data columns (total 11 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Unnamed: 0   150930 non-null  int64
#  1   country      150925 non-null  object
#  2   description  150930 non-null  object
#  3   designation  105195 non-null  object
#  4   points       150930 non-null  int64
#  5   price        137235 non-null  float64
#  6   province     150925 non-null  object
#  7   region_1     125870 non-null  object
#  8   region_2     60953 non-null   object
#  9   variety      150930 non-null  object
#  10  winery       150930 non-null  object
# dtypes: float64(1), int64(2), object(8)
# memory usage: 12.7+ MB

# %%
df.sample(10)
# Out:
#         Unnamed: 0    country  \
# 60752        60752  Australia
# 22811        22811     France
# 50665        50665  Argentina
# 112319      112319         US
# 131416      131416     France
# 40088        40088     France
# 37730        37730         US
# 10241        10241         US
# 69858        69858         US
# 110710      110710   Portugal
#
#                                               description       designation  \
# 60752   Overly green, with herbal flavors that overpow...               NaN
# 22811   Approaching maturity, here is a Riesling that ...               NaN
# 50665   Big and woody to start, with heavily toasted b...             Crios
# 112319  Once again, this bottling delivers a big, lush...      Belle Canyon
# 131416  Good density here, with tannins that spring fr...               NaN
# 40088   A wine that certainly benefits from the warm 2...  Clos St Landelin
# 37730   A new wine for Nottingham, this is a crisp, te...               NaN
# 10241   This blend of 60% Pinot Noir and 40% Chardonna...        Brut Cuvée
# 69858   Made in the Pride style, this is a big, powerf...               NaN
# 110710  From old vines, on pre-phylloxera terraces, th...   Quinta do Malho
#
#         points  price          province          region_1       region_2  \
# 60752       82    8.0   New South Wales   New South Wales            NaN
# 22811       88   25.0            Alsace            Alsace            NaN
# 50665       88   15.0  Mendoza Province           Mendoza            NaN
# 112319      91   35.0        California  Dry Creek Valley         Sonoma
# 131416      88   17.0          Bordeaux        Haut-Médoc            NaN
# 40088       85   75.0            Alsace            Alsace            NaN
# 37730       88   28.0        California       Arroyo Seco  Central Coast
# 10241       90   45.0        California   Sta. Rita Hills  Central Coast
# 69858       93   56.0        California       Sonoma-Napa    Napa-Sonoma
# 110710      91   90.0             Douro               NaN            NaN
#
#                          variety              winery
# 60752                     Merlot              Amaroo
# 22811                   Riesling               Hugel
# 50665         Cabernet Sauvignon   Dominio del Plata
# 112319                 Zinfandel               Bella
# 131416  Bordeaux-style Red Blend    Château Lieujean
# 40088                 Pinot Noir           René Muré
# 37730                   Viognier  Nottingham Cellars
# 10241            Sparkling Blend          Fesstivity
# 69858                     Merlot      Pride Mountain
# 110710            Portuguese Red      J. & F. Lurton

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df.drop('region_2', axis=1, inplace=True)

# %%
df.sample(10)
# Out:
#             country                                        description  \
# 45            Italy  A blend of 90% Sangiovese and 10% Canaiolo, th...
# 81257         Italy  This is a solid, medium-bodied wine that shoul...
# 64466      Portugal  A tight, juicy wine, with powerful new wood ar...
# 30252         Italy  This simple Pinot Grigio has aromas of pears a...
# 119519           US  A massive wine, just tremendous. Made from 97%...
# 60025   New Zealand  Like all of the Kumeu River Chardonnays, this ...
# 112545        Italy  Honey, peach and apricot characterize the nose...
# 107884      Austria  Like many naturally delicate wines in 2003, th...
# 42617     Australia  This wine's flamboyant aromas of passion fruit...
# 5821          Italy  Intense aromas of tropical fruit, banana and w...
#
#                             designation  points  price            province  \
# 45      Vigneto Odoardo Beccari Riserva      90   30.0             Tuscany
# 81257                   Colle dei Venti      87   19.0       Central Italy
# 64466         Quinta da Pellada Reserva      91    NaN                 Dão
# 30252                         Pulvernai      85    NaN  Northeastern Italy
# 119519            The Narrow & Straight      94   60.0          California
# 60025                            Estate      88   33.0               Kumeu
# 112545                              NaN      88   17.0  Northeastern Italy
# 107884           Zöbinger Heiligenstein      88   46.0             Kamptal
# 42617                          Siblings      87   20.0   Western Australia
# 5821                    Rocca dei Leoni      88   16.0      Southern Italy
#
#                           region_1                   variety          winery
# 45                Chianti Classico                 Red Blend    Vignavecchia
# 81257      Montepulciano d'Abruzzo             Montepulciano    Caldora Vini
# 64466                          NaN            Portuguese Red   Alvaro Castro
# 30252                   Alto Adige              Pinot Grigio  Castel Sallegg
# 119519                  California               White Blend         Sanguis
# 60025                          NaN                Chardonnay     Kumeu River
# 112545  Colli Orientali del Friuli                  Friulano        Ermacora
# 107884                         NaN                  Riesling          Hirsch
# 42617               Margaret River  Sauvignon Blanc-Semillon  Leeuwin Estate
# 5821                      Campania                Falanghina   Villa Matilde

# %%
predictors = df[['country', 'description', 'designation', 'province', 'region_1', 'variety', 'winery']]

# %%
predictors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150930 entries, 0 to 150929
# Data columns (total 7 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   country      150925 non-null  object
#  1   description  150930 non-null  object
#  2   designation  105195 non-null  object
#  3   province     150925 non-null  object
#  4   region_1     125870 non-null  object
#  5   variety      150930 non-null  object
#  6   winery       150930 non-null  object
# dtypes: object(7)
# memory usage: 8.1+ MB

# %% [markdown]
# ## Missing Data
#
# For the first iteration of this recommender system, I will drop observations with missing values across the board instead of being more selective. This cuts the available data in half. Next iterations could try modelling using fewer features, but more observations.

# %%
predictors.dropna(inplace=True)
# Out:
# <ipython-input-39-afd677adf460>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   predictors.dropna(inplace=True)

# %%
predictors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 85614 entries, 0 to 150928
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   country      85614 non-null  object
#  1   description  85614 non-null  object
#  2   designation  85614 non-null  object
#  3   province     85614 non-null  object
#  4   region_1     85614 non-null  object
#  5   variety      85614 non-null  object
#  6   winery       85614 non-null  object
# dtypes: object(7)
# memory usage: 5.2+ MB

# %%
predictors = predictors.reset_index()

# %%
predictors.description.duplicated().value_counts()
# Out:
# False    55449
# True     30165
# Name: description, dtype: int64

# %%
predictors.duplicated().value_counts()
# Out:
# False    85614
# dtype: int64

# %%
predictors[(predictors.description.duplicated() == True)]
# Out:
#         index country                                        description  \
# 203       300      US  This standout Rocks District wine brings earth...
# 289       423      US  The aromas on this wine are quite light, conve...
# 290       424   Spain  A mix of smoke and toast blends with fresh, cr...
# 316       480      US  Made from what Californians call the Pommard c...
# 520       810   Italy  Here's a lively Moscato made in a dry style th...
# ...       ...     ...                                                ...
# 85609  150923  France  Rich and toasty, with tiny bubbles. The bouque...
# 85610  150924  France  Really fine for a low-acid vintage, there's an...
# 85611  150926  France  Offers an intriguing nose with ginger, lime an...
# 85612  150927   Italy  This classic example comes from a cru vineyard...
# 85613  150928  France  A perfect salmon shade, with scents of peaches...
#
#                      designation           province                 region_1  \
# 203              The Funk Estate         Washington  Walla Walla Valley (WA)
# 289                      Weinbau         Washington            Wahluke Slope
# 290        Yá Cuvée 23 Brut Rosé          Catalonia                     Cava
# 316    Charles Vineyard Clone O5         California          Anderson Valley
# 520                   Bianco Dry  Sicily & Sardinia                     Noto
# ...                          ...                ...                      ...
# 85609                   Demi-Sec          Champagne                Champagne
# 85610               Diamant Bleu          Champagne                Champagne
# 85611             Cuvée Prestige          Champagne                Champagne
# 85612              Terre di Dora     Southern Italy        Fiano di Avellino
# 85613            Grand Brut Rosé          Champagne                Champagne
#
#                variety                   winery
# 203              Syrah                   Saviah
# 289           Grenache                Sol Stone
# 290    Sparkling Blend                Sumarroca
# 316         Pinot Noir                Foursight
# 520            Moscato                  Planeta
# ...                ...                      ...
# 85609  Champagne Blend                 Jacquart
# 85610  Champagne Blend  Heidsieck & Co Monopole
# 85611  Champagne Blend                H.Germain
# 85612      White Blend                Terredora
# 85613  Champagne Blend                   Gosset
#
# [30165 rows x 8 columns]

# %%
predictors.sample(10)
# Out:
#         index    country                                        description  \
# 43187   75262     France  A wine that is now showing some maturity, the ...
# 1460     2419      Italy  The nose is rather closed on this 80% Sangiove...
# 74923  130863  Argentina  A rough, harsh nose of mustard and burnt stems...
# 16002   27233      Italy  Creamy and fresh, this sparkling Lugana shows ...
# 63998  111471         US  Soft and generous in fruity flavor, this has p...
# 72101  125727         US  The first of Morgan's '07 Pinots to be release...
# 58570  102244         US  Cooked or burnt black currants and caramelized...
# 34172   58498      Italy  Poggio Salvi's Brunello Riserva offers genuine...
# 65209  113962         US  The blend is mostly Merlot, with Syrah and Cab...
# 60577  105920     France  92-94 Barrel sample. A powerful, but velvet te...
#
#                              designation          province  \
# 43187               Seigneurs d'Aiguilhe          Bordeaux
# 1460                      Gran Selezione           Tuscany
# 74923                            Premium  Mendoza Province
# 16002                            Brut 36          Lombardy
# 63998                        Rockin' One        California
# 72101                      Twelve Clones        California
# 58570                            Reserve        California
# 34172                            Riserva           Tuscany
# 65209                     Red Table Wine        Washington
# 60577  Les Forts de Latour Barrel sample          Bordeaux
#
#                      region_1                   variety  \
# 43187      Côtes de Castillon  Bordeaux-style Red Blend
# 1460         Chianti Classico                 Red Blend
# 74923                 Mendoza                Chardonnay
# 16002                  Lugana                  Turbiana
# 63998             Paso Robles     Rhône-style Red Blend
# 72101   Santa Lucia Highlands                Pinot Noir
# 58570        Sierra Foothills                     Syrah
# 34172  Brunello di Montalcino         Sangiovese Grosso
# 65209    Columbia Valley (WA)                 Red Blend
# 60577                Pauillac  Bordeaux-style Red Blend
#
#                          winery
# 43187        Château d'Aiguilhe
# 1460                  Livernano
# 74923          Sur de los Andes
# 16002                    Citari
# 63998                      Cass
# 72101                    Morgan
# 58570                   Naggiar
# 34172        Villa Poggio Salvi
# 65209  Magnificent Wine Company
# 60577            Château Latour

# %% [markdown]
# ## Feature Engineering & Unique Names for Wines

# %%
## Creating a more detailed name for each wine by combining Winery and Designation

predictors['name'] = predictors['winery'] + ', ' + predictors['designation']

# %%
predictors.drop('index', axis=1, inplace=True)

# %%
predictors.sample(10)
# Out:
#          country                                        description  \
# 12935         US  An excellent Finger Lakes pick, it's redolent ...
# 393           US  A striking shade of amber/orange, this soft an...
# 8739          US  Creamy, yeasty lees, 100% new French oak and i...
# 29169  Argentina  Aromas of sweet melon and honey suggest an inn...
# 2157          US  Black cherries, sagebrush, dried rose petals, ...
# 19770         US  This wine comes with chewy tannins and supple ...
# 19858      Italy  This opens with aromas of pressed violets, ros...
# 25970         US  Opening with a nose of sweet roses, it then de...
# 9512      France  This wine is so soft it is almost without tast...
# 22912      Italy  Easy and fresh, this ruby-colored wine opens w...
#
#                                         designation    province  \
# 12935                               Limited Release    New York
# 393                                  Wirtz Vineyard      Oregon
# 8739   Bonita's Hill Don Miguel Vineyard Unfiltered  California
# 29169                                     Coleccion       Other
# 2157                                Cotes-du-Rôbles  California
# 19770                  Church Creek Vintner's Blend    Virginia
# 19858                           Riserva Castelgreve     Tuscany
# 25970                       Testa Vineyard Old Vine  California
# 9512                                       La Vache    Bordeaux
# 22912                             Grotta del Ninfeo      Veneto
#
#                        region_1                        variety  \
# 12935               Cayuga Lake                     Chardonnay
# 393           Willamette Valley                     Pinot Gris
# 8739       Russian River Valley                     Chardonnay
# 29169          Calchaquí Valley                     Chardonnay
# 2157                Paso Robles          Rhône-style Red Blend
# 19770  Virginia's Eastern Shore       Bordeaux-style Red Blend
# 19858          Chianti Classico                     Sangiovese
# 25970                 Mendocino                      Carignane
# 9512              Bordeaux Rosé                           Rosé
# 22912              Valpolicella  Corvina, Rondinella, Molinara
#
#                        winery  \
# 12935                  Hosmer
# 393            Big Table Farm
# 8739           Marimar Estate
# 29169           Michel Torino
# 2157                   Eberle
# 19770                 Chatham
# 19858  Castelli del Grevepesa
# 25970            Horse & Plow
# 9512             Maison Bouey
# 22912     Domenico Fraccaroli
#
#                                                     name
# 12935                            Hosmer, Limited Release
# 393                       Big Table Farm, Wirtz Vineyard
# 8739   Marimar Estate, Bonita's Hill Don Miguel Viney...
# 29169                           Michel Torino, Coleccion
# 2157                             Eberle, Cotes-du-Rôbles
# 19770              Chatham, Church Creek Vintner's Blend
# 19858        Castelli del Grevepesa, Riserva Castelgreve
# 25970              Horse & Plow, Testa Vineyard Old Vine
# 9512                              Maison Bouey, La Vache
# 22912             Domenico Fraccaroli, Grotta del Ninfeo

# %%
## Leaving this in for future ideas

## Creating a UID for each wine by combining all data into one variable

#predictors['uid'] = predictors['winery'] + ', ' + predictors['designation'] + ', ' + predictors['country'] + ', ' + predictors['description'] + ', ' + predictors['province'] + ', ' + predictors['region_1'] + ', ' + predictors['variety']

# %% [markdown]
# ### Removing Duplicate Values

# %%
predictors.drop_duplicates(inplace=True)

# %%
predictors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 55461 entries, 0 to 85141
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   country      55461 non-null  object
#  1   description  55461 non-null  object
#  2   designation  55461 non-null  object
#  3   province     55461 non-null  object
#  4   region_1     55461 non-null  object
#  5   variety      55461 non-null  object
#  6   winery       55461 non-null  object
#  7   name         55461 non-null  object
# dtypes: object(8)
# memory usage: 3.8+ MB

# %%
predictors.country.value_counts()
# Out:
# US           26157
# Italy        10537
# France        9761
# Spain         4317
# Argentina     2428
# Australia     2147
# Canada         114
# Name: country, dtype: int64

# %%
predictors.name.duplicated().value_counts()
# Out:
# False    33549
# True     21912
# Name: name, dtype: int64

# %% [markdown]
# In order for the end user to recieve recommendations, using this model and approach, they need to enter a unique name for a wine they like. With so many duplicates this becomes tricky. For now I will drop duplicated wine values, which significantly reduces the volume of data but solved the uniqueness issue. There is almost certainly a better way around this!

# %%
predictors.drop_duplicates(subset='name', keep='last', inplace=True)

# %%
predictors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 33549 entries, 1 to 85141
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   country      33549 non-null  object
#  1   description  33549 non-null  object
#  2   designation  33549 non-null  object
#  3   province     33549 non-null  object
#  4   region_1     33549 non-null  object
#  5   variety      33549 non-null  object
#  6   winery       33549 non-null  object
#  7   name         33549 non-null  object
# dtypes: object(8)
# memory usage: 2.3+ MB

# %%
predictors.reset_index(inplace=True)

# %%
predictors.drop('index', axis=1, inplace=True)

# %% [markdown]
# ## Vectorizing With Tfidf

# %%
vectors = TfidfVectorizer(min_df = 3,
                         max_features = None,
                         strip_accents = 'unicode',
                         analyzer = 'word',
                         token_pattern = '\w{2,}',
                         ngram_range = (1,3),
                         stop_words = 'english')

# %%
vectors_matrix = vectors.fit_transform(predictors['description'])

# %%
vectors_matrix.shape
# Out:
# (33549, 73445)

# %% [markdown]
# ## Calculating Similarity

# %%
sig_kern = sigmoid_kernel(vectors_matrix, vectors_matrix)

# %%
sig_kern
# Out:
# array([[0.76159987, 0.76159421, 0.76159418, ..., 0.76159416, 0.76159422,
#         0.76159418],
#        [0.76159421, 0.76159987, 0.76159418, ..., 0.76159417, 0.76159417,
#         0.76159417],
#        [0.76159418, 0.76159418, 0.76159987, ..., 0.76159418, 0.76159418,
#         0.76159418],
#        ...,
#        [0.76159416, 0.76159417, 0.76159418, ..., 0.76159987, 0.76159417,
#         0.76159423],
#        [0.76159422, 0.76159417, 0.76159418, ..., 0.76159417, 0.76159987,
#         0.76159419],
#        [0.76159418, 0.76159417, 0.76159418, ..., 0.76159423, 0.76159419,
#         0.76159987]])

# %%
index = pd.Series(predictors.index, index=predictors['name']).drop_duplicates()

# %%
index['Sobon Estate, Fiddletown']
# Out:
# 21347

# %%
def recommend_wine(name, sig_kern=sig_kern):
    indx = index[name]
    sigmoid_score = list(enumerate(sig_kern[indx]))
    sigmoid_score = sorted(sigmoid_score, key = lambda x:x[1], reverse = True)
    sigmoid_score = sigmoid_score[1:4]
    position = [i[0] for i in sigmoid_score]
    return predictors.iloc[position]

# %%
recommend_wine('Castelli del Grevepesa, Riserva Castelgreve')
# Out:
#          country                                        description  \
# 19711      Italy  Made with Sangiovese, this shows ripe berry an...
# 30485  Argentina  This wine shows molasses and Boston baked bean...
# 22443      Italy  From the Classico zone of Amarone, this shows ...
#
#                  designation          province  \
# 19711    Terra Rossa Riserva           Tuscany
# 30485  Paris Goulart Reserva  Mendoza Province
# 22443            Corte Vaona            Veneto
#
#                                   region_1                        variety  \
# 19711                 Chianti Colli Senesi                     Sangiovese
# 30485                              Mendoza      Malbec-Cabernet Sauvignon
# 22443  Amarone della Valpolicella Classico  Corvina, Rondinella, Molinara
#
#                     winery                                      name
# 19711  Tenuta di Trecciano  Tenuta di Trecciano, Terra Rossa Riserva
# 30485       Bodega Goulart     Bodega Goulart, Paris Goulart Reserva
# 22443               Novaia                       Novaia, Corte Vaona
