# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel, sigmoid_kernel

# %% [markdown]
# # Building a Wine Recommendation System
#
# Creating a content-based recommendation system through using NLP modelinng on sommellier reviews.

# %%
df = pd.read_csv('../../Data/wine_data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150930 entries, 0 to 150929
# Data columns (total 11 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Unnamed: 0   150930 non-null  int64
#  1   country      150925 non-null  object
#  2   description  150930 non-null  object
#  3   designation  105195 non-null  object
#  4   points       150930 non-null  int64
#  5   price        137235 non-null  float64
#  6   province     150925 non-null  object
#  7   region_1     125870 non-null  object
#  8   region_2     60953 non-null   object
#  9   variety      150930 non-null  object
#  10  winery       150930 non-null  object
# dtypes: float64(1), int64(2), object(8)
# memory usage: 12.7+ MB

# %%
df.sample(10)
# Out:
#         Unnamed: 0 country                                        description  \
# 96722        96722      US  Made from Cabernet Sauvignon, Merlot and Petit...
# 108942      108942  France  While it has very bready and yeasty aromas, yo...
# 40902        40902   Italy  This playful blend of air-dried white grapes (...
# 134975      134975   Italy  There are some tertiary aromas here of cola, M...
# 83561        83561   Italy  Very informal and light, this shows fresh frui...
# 110519      110519      US  Good fruit from the Riverbend vineyard brings ...
# 117431      117431      US  With 6 Rhône varieties, including Viognier, th...
# 77216        77216  Greece  Exotic pineapple and melon fruit aromas lead o...
# 93550        93550   Italy  San Polo has shown very impressive work lately...
# 123069      123069      US  The 2007 vintage was a fabulous one for Willia...
#
#                       designation  points  price        province  \
# 96722                     Trilogy      91   65.0      California
# 108942                        NaN      94  120.0       Champagne
# 40902   Alba Chiara Passito 500ml      83   12.0          Veneto
# 134975               Carlin Burel      85   18.0        Piedmont
# 83561             Pizzo del Vento      84   12.0  Southern Italy
# 110519            Shameless Hussy      87   20.0      Washington
# 117431             Rhône Red Wine      87   40.0      California
# 77216                         NaN      87   30.0     Peloponnese
# 93550                         NaN      94   75.0         Tuscany
# 123069            Papera Vineyard      94   48.0      California
#
#                       region_1         region_2                   variety  \
# 96722              Napa Valley             Napa  Bordeaux-style Red Blend
# 108942               Champagne              NaN           Champagne Blend
# 40902                   Veneto              NaN               White Blend
# 134975         Dolcetto d'Alba              NaN                  Dolcetto
# 83561                  Salento              NaN                Negroamaro
# 110519           Wahluke Slope  Columbia Valley                     Syrah
# 117431           Central Coast    Central Coast     Rhône-style Red Blend
# 77216                      NaN              NaN              Petroulianos
# 93550   Brunello di Montalcino              NaN         Sangiovese Grosso
# 123069    Russian River Valley           Sonoma                 Zinfandel
#
#                     winery
# 96722        Flora Springs
# 108942  Jacquesson et Fils
# 40902            Pizzolato
# 134975     Rivetti Massimo
# 83561                Miali
# 110519     Hard Row To Hoe
# 117431      Clos La Chance
# 77216             Vatistas
# 93550             San Polo
# 123069     Williams Selyem

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df.drop('region_2', axis=1, inplace=True)

# %%
df.sample(10)
# Out:
#           country                                        description  \
# 21082      France  91-93. Barrel sample. This has an herbal chara...
# 63836          US  Shows the bright, forward cherry flavors and z...
# 8810           US  Dark in the glass, this blend of 75% Grenache ...
# 4507      Morocco  From the first whiff of cherry, cranberry and ...
# 137773  Argentina  Tight, concentrated and deep, with rubbery aro...
# 112361         US  Powerful aromatics lead to powerful fruity fla...
# 45905   Australia  Good luck finding a Cabernet for $15 that offe...
# 37803       Spain  Pungent and sweaty smelling on first blush, al...
# 969            US  Raisin and white pepper aromas, ripe fruit, fl...
# 65269          US  Rustic in country-style tannins, with a hint o...
#
#               designation  points  price         province           region_1  \
# 21082       Barrel Sample      92    NaN         Bordeaux            Pomerol
# 63836                 NaN      84   15.0       California  San Benito County
# 8810      First Born King      91   34.0       California        Paso Robles
# 4507                  NaN      90   17.0           Zenata                NaN
# 137773  Don David Reserve      89   17.0            Other           Cafayate
# 112361      Lotus Lot #45      87   28.0       California        San Pasqual
# 45905       Thomas Hyland      89   15.0  South Australia    South Australia
# 37803                 NaN      87   22.0          Galicia        Rías Baixas
# 969         Whole Cluster      90   44.0       California    Anderson Valley
# 65269                 NaN      84    9.0       California         California
#
#                          variety               winery
# 21082   Bordeaux-style Red Blend   Château Providence
# 63836                 Sangiovese         Ca' del Solo
# 8810       Rhône-style Red Blend  Rendarrio Vineyards
# 4507                       Syrah         Ouled Thaleb
# 137773                     Syrah        Michel Torino
# 112361   Rhône-style White Blend               Orfila
# 45905         Cabernet Sauvignon             Penfolds
# 37803                   Albariño         Don Olegario
# 969                   Pinot Noir             Stemmler
# 65269                     Merlot             Eastwood

# %%
predictors = df[['country', 'description', 'designation', 'province', 'region_1', 'variety', 'winery']]

# %%
predictors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150930 entries, 0 to 150929
# Data columns (total 7 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   country      150925 non-null  object
#  1   description  150930 non-null  object
#  2   designation  105195 non-null  object
#  3   province     150925 non-null  object
#  4   region_1     125870 non-null  object
#  5   variety      150930 non-null  object
#  6   winery       150930 non-null  object
# dtypes: object(7)
# memory usage: 8.1+ MB

# %% [markdown]
# ## Missing Data
#
# For the first iteration of this recommender system, I will drop observations with missing values across the board instead of being more selective. This cuts the available data in half. Next iterations could try modelling using fewer features, but more observations.

# %%
predictors.dropna(inplace=True)
# Out:
# <ipython-input-377-afd677adf460>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   predictors.dropna(inplace=True)

# %%
predictors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 85614 entries, 0 to 150928
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   country      85614 non-null  object
#  1   description  85614 non-null  object
#  2   designation  85614 non-null  object
#  3   province     85614 non-null  object
#  4   region_1     85614 non-null  object
#  5   variety      85614 non-null  object
#  6   winery       85614 non-null  object
# dtypes: object(7)
# memory usage: 5.2+ MB

# %%
predictors = predictors.reset_index()

# %%
predictors.description.duplicated().value_counts()
# Out:
# False    55449
# True     30165
# Name: description, dtype: int64

# %%
predictors.duplicated().value_counts()
# Out:
# False    85614
# dtype: int64

# %%
predictors[(predictors.description.duplicated() == True)]
# Out:
#         index country                                        description  \
# 203       300      US  This standout Rocks District wine brings earth...
# 289       423      US  The aromas on this wine are quite light, conve...
# 290       424   Spain  A mix of smoke and toast blends with fresh, cr...
# 316       480      US  Made from what Californians call the Pommard c...
# 520       810   Italy  Here's a lively Moscato made in a dry style th...
# ...       ...     ...                                                ...
# 85609  150923  France  Rich and toasty, with tiny bubbles. The bouque...
# 85610  150924  France  Really fine for a low-acid vintage, there's an...
# 85611  150926  France  Offers an intriguing nose with ginger, lime an...
# 85612  150927   Italy  This classic example comes from a cru vineyard...
# 85613  150928  France  A perfect salmon shade, with scents of peaches...
#
#                      designation           province                 region_1  \
# 203              The Funk Estate         Washington  Walla Walla Valley (WA)
# 289                      Weinbau         Washington            Wahluke Slope
# 290        Yá Cuvée 23 Brut Rosé          Catalonia                     Cava
# 316    Charles Vineyard Clone O5         California          Anderson Valley
# 520                   Bianco Dry  Sicily & Sardinia                     Noto
# ...                          ...                ...                      ...
# 85609                   Demi-Sec          Champagne                Champagne
# 85610               Diamant Bleu          Champagne                Champagne
# 85611             Cuvée Prestige          Champagne                Champagne
# 85612              Terre di Dora     Southern Italy        Fiano di Avellino
# 85613            Grand Brut Rosé          Champagne                Champagne
#
#                variety                   winery
# 203              Syrah                   Saviah
# 289           Grenache                Sol Stone
# 290    Sparkling Blend                Sumarroca
# 316         Pinot Noir                Foursight
# 520            Moscato                  Planeta
# ...                ...                      ...
# 85609  Champagne Blend                 Jacquart
# 85610  Champagne Blend  Heidsieck & Co Monopole
# 85611  Champagne Blend                H.Germain
# 85612      White Blend                Terredora
# 85613  Champagne Blend                   Gosset
#
# [30165 rows x 8 columns]

# %%
predictors.sample(10)
# Out:
#         index    country                                        description  \
# 58382  101874      Italy  This darkly saturated Riserva has an inky, rip...
# 63466  110560      Italy  Bortolotti makes a well-priced Non-DOC Prosecc...
# 28428   48919     France  Pure black berry juice, ripe and solid, this i...
# 56155   97929         US  Crisp acidity gives this Pinot a tart bite, bu...
# 47299   82652  Argentina  An apple aroma comes with a tinge of mild oak,...
# 8799    14957     France  The cherry, leather and chocolate aromas are a...
# 21935   37394      Italy  Petruccino is a delightful and elegant wine wi...
# 35399   60742         US  A soft entry quickly leads into a short, tart,...
# 83320  146088  Australia  Like the label says, no oak has touched this w...
# 2906     4868         US  Fig and fennel star in this block-designated w...
#
#                           designation          province  \
# 58382  Riserva Castello di Monna Lisa           Tuscany
# 63466                Single Extra Dry            Veneto
# 28428                Chatons du Cèdre  Southwest France
# 56155          Sleepy Hollow Vineyard        California
# 47299                            1300  Mendoza Province
# 8799                        La Devèze      Rhône Valley
# 21935                      Petruccino           Tuscany
# 35399               Boushey Vineyards        Washington
# 83320                         Unoaked          Victoria
# 2906                      Block 4SB20        California
#
#                     region_1                variety               winery
# 58382       Chianti Classico             Sangiovese    Villa Vignamaggio
# 63466    Prosecco del Veneto               Prosecco           Bortolotti
# 28428                 Cahors                 Malbec     Château du Cèdre
# 56155  Santa Lucia Highlands             Pinot Noir            Twin Oaks
# 47299             Uco Valley             Chardonnay             Andeluna
# 8799          Côtes du Rhône  Rhône-style Red Blend  Domaine de Dionysos
# 21935                  Orcia              Red Blend         Podere Forte
# 35399          Yakima Valley                  Syrah         Three Rivers
# 83320   Mornington Peninsula             Chardonnay         Willow Creek
# 2906           Sonoma Valley        Sauvignon Blanc                Kunde

# %% [markdown]
# ## Feature Engineering & Unique Names for Wines

# %%
## Creating a more detailed name for each wine by combining Winery and Designation

predictors['name'] = predictors['winery'] + ', ' + predictors['designation']

# %%
predictors.drop('index', axis=1, inplace=True)

# %%
predictors.sample(10)
# Out:
#       country                                        description  \
# 16148      US  The somewhat prominent herb aromas don't seem ...
# 55976   Spain  Roll out the barrel, or the staves, or the oak...
# 84508      US  Powerful, youthful and still a bit raw, the ne...
# 64053  France  This wine has a smoky character with aromas of...
# 76061  France  91-93 Barrel sample. There is a good structure...
# 3712       US  A 100% Cabernet Sauvignon from the M5 block of...
# 40785      US  Laurent Montalieu is the winemaker behind the ...
# 31443      US  A harshly sharp, rather green wine, with scour...
# 36817      US  A very nice effort at this price, it's smooth ...
# 31171   Italy  From the far-away 1994 vintage, this aged meto...
#
#                   designation      province  \
# 16148  Pepper Bridge Vineyard    Washington
# 55976                  Veleta     Andalucia
# 84508          Chaleur Estate    Washington
# 64053          Les Caillottes  Loire Valley
# 76061           Barrel sample      Bordeaux
# 3712   Stagecoach Vineyard M5    California
# 40785            Spruce Goose        Oregon
# 31443                  Estate    California
# 36817            Kamiakin Red    Washington
# 31171            Brut Riserva      Lombardy
#
#                                       region_1                   variety  \
# 16148                  Walla Walla Valley (WA)                    Merlot
# 55976  Vino de la Tierra Contraviesa Alpujarra                Chardonnay
# 84508                     Columbia Valley (WA)                 Red Blend
# 64053                             Pouilly-Fumé           Sauvignon Blanc
# 76061                                  Pomerol  Bordeaux-style Red Blend
# 3712                               Napa Valley        Cabernet Sauvignon
# 40785                        Willamette Valley                  Riesling
# 31443                                El Dorado        Cabernet Sauvignon
# 36817                            Yakima Valley                 Red Blend
# 31171                             Franciacorta           Sparkling Blend
#
#                       winery                                    name
# 16148           Two Vintners    Two Vintners, Pepper Bridge Vineyard
# 55976     Dominio Buenavista              Dominio Buenavista, Veleta
# 84508                DeLille                 DeLille, Chaleur Estate
# 64053  Fournier Père et Fils   Fournier Père et Fils, Les Caillottes
# 76061          Château Nenin            Château Nenin, Barrel sample
# 3712          Krupp Brothers  Krupp Brothers, Stagecoach Vineyard M5
# 40785    Evergreen Vineyards       Evergreen Vineyards, Spruce Goose
# 31443          Wofford Acres                   Wofford Acres, Estate
# 36817      Sheridan Vineyard         Sheridan Vineyard, Kamiakin Red
# 31171              Cornaleto                 Cornaleto, Brut Riserva

# %%
## Creating a UID for each wine by combining all data into one variable

predictors['uid'] = predictors['winery'] + ', ' + predictors['designation'] + ', ' + predictors['country'] + ', ' + predictors['description'] + ', ' + predictors['province'] + ', ' + predictors['region_1'] + ', ' + predictors['variety']

# %%
predictors.sample(10)
# Out:
#       country                                        description  \
# 68781      US  Silky and dry, but sharp and herbal, with not ...
# 42100      US  Easy to like for its orange and pear soda, van...
# 19738      US  A mix of Cabernet and Merlot, with small amoun...
# 5285       US  This is a delicate wine, true to variety with ...
# 43722      US  This shows the streamlined acidity and mineral...
# 29278  France  A classic and fun Nouveau, this has an extra s...
# 47178   Italy  This offers soft, slightly sweet aromas of che...
# 13801      US  Racy and bright, with high acidity framing dry...
# 53632      US  A blend of grapes from three vineyard sites, t...
# 16988  France  86–88. Barrel sample. With a chemical aroma, t...
#
#                  designation       province                 region_1  \
# 68781         Coastal Series     California               California
# 42100     Artisan Collection     California               California
# 19738        Proprietary Red     Washington     Columbia Valley (WA)
# 5285             Pishon Bloc         Oregon            Umpqua Valley
# 43722  Taylor Ridge Vineyard     California             Sonoma Coast
# 29278                Nouveau     Beaujolais               Beaujolais
# 47178            Montipagano  Central Italy  Montepulciano d'Abruzzo
# 13801                Reserve     California     Russian River Valley
# 53632                    Dry       New York             Finger Lakes
# 16988          Barrel Sample       Bordeaux                   Barsac
#
#                           variety              winery  \
# 68781                  Pinot Noir         Jenica Peak
# 42100                  Chardonnay           HandCraft
# 19738    Bordeaux-style Red Blend  Swiftwater Cellars
# 5285                   Pinot Noir             Reustle
# 43722                  Chardonnay              Boheme
# 29278                       Gamay              Thorin
# 47178               Montepulciano        Umani Ronchi
# 13801             Sauvignon Blanc       Frei Brothers
# 53632                    Riesling       Heart & Hands
# 16988  Bordeaux-style White Blend        Château Suau
#
#                                       name  \
# 68781          Jenica Peak, Coastal Series
# 42100        HandCraft, Artisan Collection
# 19738  Swiftwater Cellars, Proprietary Red
# 5285                  Reustle, Pishon Bloc
# 43722        Boheme, Taylor Ridge Vineyard
# 29278                      Thorin, Nouveau
# 47178            Umani Ronchi, Montipagano
# 13801               Frei Brothers, Reserve
# 53632                   Heart & Hands, Dry
# 16988          Château Suau, Barrel Sample
#
#                                                      uid
# 68781  Jenica Peak, Coastal Series, US, Silky and dry...
# 42100  HandCraft, Artisan Collection, US, Easy to lik...
# 19738  Swiftwater Cellars, Proprietary Red, US, A mix...
# 5285   Reustle, Pishon Bloc, US, This is a delicate w...
# 43722  Boheme, Taylor Ridge Vineyard, US, This shows ...
# 29278  Thorin, Nouveau, France, A classic and fun Nou...
# 47178  Umani Ronchi, Montipagano, Italy, This offers ...
# 13801  Frei Brothers, Reserve, US, Racy and bright, w...
# 53632  Heart & Hands, Dry, US, A blend of grapes from...
# 16988  Château Suau, Barrel Sample, France, 86–88. Ba...

# %%
predictors.winery.duplicated().value_counts()
# Out:
# True     46024
# False     9437
# Name: winery, dtype: int64

# %%
## Region and Variety

predictors['des_reg_var'] = predictors['designation'] + ', ' + predictors['region_1'] + ', ' + predictors['variety']

# %%
predictors.des_reg_var.duplicated().value_counts()
# Out:
# True     50896
# False    34718
# Name: des_reg_var, dtype: int64

# %%
predictors.sample(10).des_reg_var
# Out:
# 21242              Jenkins Ranch, Sonoma Coast, Pinot Noir
# 74645          Àn, Vi de la Terra Illes Balears, Red Blend
# 6514               Hatschbourg Grand Cru, Alsace, Riesling
# 23008               Cool Climate, Sonoma Coast, Pinot Noir
# 1353                             Colarej, Barolo, Nebbiolo
# 52466    Camp 4 Vineyard, Santa Ynez Valley, Grenache B...
# 82482    Diamond Mountain Ranch, Napa Valley, Cabernet ...
# 13594         Extra Dry, Columbia Valley (WA), White Blend
# 39320        Reserve, Alexander Valley, Cabernet Sauvignon
# 82931    Le Serre Nuove, Bolgheri, Cabernet Sauvignon-M...
# Name: des_reg_var, dtype: object

# %% [markdown]
# ### Removing Duplicate Values

# %%
predictors.drop_duplicates(inplace=True)

# %%
predictors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 55461 entries, 0 to 85141
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   country      55461 non-null  object
#  1   description  55461 non-null  object
#  2   designation  55461 non-null  object
#  3   province     55461 non-null  object
#  4   region_1     55461 non-null  object
#  5   variety      55461 non-null  object
#  6   winery       55461 non-null  object
#  7   name         55461 non-null  object
#  8   uid          55461 non-null  object
# dtypes: object(9)
# memory usage: 4.2+ MB

# %%
predictors.country.value_counts()
# Out:
# US           26157
# Italy        10537
# France        9761
# Spain         4317
# Argentina     2428
# Australia     2147
# Canada         114
# Name: country, dtype: int64

# %%
predictors.uid.duplicated().value_counts()
# Out:
# False    55461
# Name: uid, dtype: int64

# %%
predictors.name.duplicated().value_counts()
# Out:
# False    33549
# True     21912
# Name: name, dtype: int64

# %% [markdown]
# ## Reducing Scope of Wines
#
# In order to be able to model locally, I will reduce the scope of the project to focus only on winde producing regions outside of the United States.

# %%
non_usa = predictors[(predictors.country != 'US')]

# %%
non_usa.reset_index(inplace=True)

# %%
non_usa.drop('index', axis=1, inplace=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
non_usa
# Out:
#          country                                        description  \
# 0          Spain  Ripe aromas of fig, blackberry and cassis are ...
# 1         France  This is the top wine from La Bégude, named aft...
# 2          Spain  Deep, dense and pure from the opening bell, th...
# 3          Spain  Slightly gritty black-fruit aromas include a s...
# 4          Spain  Lush cedary black-fruit aromas are luxe and of...
# ...          ...                                                ...
# 29299  Argentina  Standard aromas in the berry and beet range is...
# 29300  Australia  Starts off with grassy, fresh herbal aromas an...
# 29301  Argentina  Yellowish in color, with a heavy, somewhat cre...
# 29302  Argentina  Dark and dense, with extracted black cherry, l...
# 29303     France  Opens with spice aromas that seem a bit unusua...
#
#                                 designation           province  \
# 0      Carodorum Selección Especial Reserva     Northern Spain
# 1                                La Brûlade           Provence
# 2                                 Numanthia     Northern Spain
# 3                                 San Román     Northern Spain
# 4                   Carodorum Único Crianza     Northern Spain
# ...                                     ...                ...
# 29299                        Silver Reserve              Other
# 29300                              Zeepaard  Western Australia
# 29301                               Organic   Mendoza Province
# 29302                               Organic   Mendoza Province
# 29303                                Andlau             Alsace
#
#                 region_1             variety                   winery  \
# 0                   Toro       Tinta de Toro  Bodega Carmen Rodríguez
# 1                 Bandol  Provence red blend     Domaine de la Bégude
# 2                   Toro       Tinta de Toro                Numanthia
# 3                   Toro       Tinta de Toro                 Maurodos
# 4                   Toro       Tinta de Toro  Bodega Carmen Rodríguez
# ...                  ...                 ...                      ...
# 29299    Famatina Valley               Syrah                     Raza
# 29300  Western Australia     Sauvignon Blanc           West Cape Howe
# 29301          Tupungato          Chardonnay    Domaine Jean Bousquet
# 29302          Tupungato              Malbec    Domaine Jean Bousquet
# 29303             Alsace            Riesling        Marc Kreydenweiss
#
#                                                     name  \
# 0      Bodega Carmen Rodríguez, Carodorum Selección E...
# 1                       Domaine de la Bégude, La Brûlade
# 2                                   Numanthia, Numanthia
# 3                                    Maurodos, San Román
# 4       Bodega Carmen Rodríguez, Carodorum Único Crianza
# ...                                                  ...
# 29299                               Raza, Silver Reserve
# 29300                           West Cape Howe, Zeepaard
# 29301                     Domaine Jean Bousquet, Organic
# 29302                     Domaine Jean Bousquet, Organic
# 29303                          Marc Kreydenweiss, Andlau
#
#                                                      uid
# 0      Bodega Carmen Rodríguez, Carodorum Selección E...
# 1      Domaine de la Bégude, La Brûlade, France, This...
# 2      Numanthia, Numanthia, Spain, Deep, dense and p...
# 3      Maurodos, San Román, Spain, Slightly gritty bl...
# 4      Bodega Carmen Rodríguez, Carodorum Único Crian...
# ...                                                  ...
# 29299  Raza, Silver Reserve, Argentina, Standard arom...
# 29300  West Cape Howe, Zeepaard, Australia, Starts of...
# 29301  Domaine Jean Bousquet, Organic, Argentina, Yel...
# 29302  Domaine Jean Bousquet, Organic, Argentina, Dar...
# 29303  Marc Kreydenweiss, Andlau, France, Opens with ...
#
# [29304 rows x 9 columns]

# %% [markdown]
# ## Vectorizing With Tfidf

# %%
vectors = TfidfVectorizer(min_df = 3,
                         max_features = None,
                         strip_accents = 'unicode',
                         analyzer = 'word',
                         token_pattern = '\w{2,}',
                         ngram_range = (1,3),
                         stop_words = 'english')

# %%
vectors_matrix = vectors.fit_transform(non_usa['description'])

# %%
vectors_matrix.shape
# Out:
# (29304, 65978)

# %% [markdown]
# ## Calculating Similarity

# %%
sig_kern = sigmoid_kernel(vectors_matrix, vectors_matrix)

# %%
sig_kern
# Out:
# array([[0.76160052, 0.76159418, 0.76159482, ..., 0.76159436, 0.76159444,
#         0.76159421],
#        [0.76159418, 0.76160052, 0.76159418, ..., 0.76159416, 0.76159416,
#         0.76159416],
#        [0.76159482, 0.76159418, 0.76160052, ..., 0.76159419, 0.76159429,
#         0.76159421],
#        ...,
#        [0.76159436, 0.76159416, 0.76159419, ..., 0.76160052, 0.76159427,
#         0.76159419],
#        [0.76159444, 0.76159416, 0.76159429, ..., 0.76159427, 0.76160052,
#         0.76159418],
#        [0.76159421, 0.76159416, 0.76159421, ..., 0.76159419, 0.76159418,
#         0.76160052]])

# %%
index = pd.Series(non_usa.index, index=non_usa['winery']).drop_duplicates()

# %%
index['Maurodos']
# Out:
# winery
# Maurodos        3
# Maurodos     2364
# Maurodos     5939
# Maurodos    10949
# Maurodos    13269
# Maurodos    21319
# Maurodos    24576
# Maurodos    26911
# dtype: int64

# %%
def recommend_wine(winery, sig_kern=sig_kern):
    indx = index[winery]
    sigmoid_score = list(enumerate(sig_kern[indx]))
    sigmoid_score = sorted(sigmoid_score, key = lambda x:x[1], reverse = True)
    sigmoid_score = sigmoid_score[1:3]
    wines = [i[0] for i in sigmoid_score]
    return non_usa.iloc[wines]

# %%
recommend_wine('Maurodos')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-358-9972336981d1> in <module>
# ----> 1 recommend_wine('Maurodos')
#
# <ipython-input-357-13920de20b2b> in recommend_wine(winery, sig_kern)
#       2     indx = index[winery]
#       3     sigmoid_score = list(enumerate(sig_kern[indx]))
# ----> 4     sigmoid_score = sorted(sigmoid_score, key = lambda x:x[1], reverse = True)
#       5     sigmoid_score = sigmoid_score[1:3]
#       6     wines = [i[0] for i in sigmoid_score]
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
