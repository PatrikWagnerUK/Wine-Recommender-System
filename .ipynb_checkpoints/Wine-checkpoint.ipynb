# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel, sigmoid_kernel

# %% [markdown]
# # Building a Wine Recommendation System
#
# Creating a content-based recommendation system through using NLP modelinng on sommellier reviews.

# %%
df = pd.read_csv('../../Data/wine_data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150930 entries, 0 to 150929
# Data columns (total 11 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Unnamed: 0   150930 non-null  int64
#  1   country      150925 non-null  object
#  2   description  150930 non-null  object
#  3   designation  105195 non-null  object
#  4   points       150930 non-null  int64
#  5   price        137235 non-null  float64
#  6   province     150925 non-null  object
#  7   region_1     125870 non-null  object
#  8   region_2     60953 non-null   object
#  9   variety      150930 non-null  object
#  10  winery       150930 non-null  object
# dtypes: float64(1), int64(2), object(8)
# memory usage: 12.7+ MB

# %%
df.sample(10)
# Out:
#         Unnamed: 0      country  \
# 117329      117329           US
# 133826      133826       Greece
# 7205          7205      Austria
# 142953      142953       France
# 51881        51881           US
# 131667      131667           US
# 78961        78961  New Zealand
# 74060        74060           US
# 90313        90313           US
# 121213      121213           US
#
#                                               description  \
# 117329  This is a pleasant bottle, with pretty varieta...
# 133826  The lush nose of Viognier—fresh flowers, honey...
# 7205    Although restrained on the nose, this wine lea...
# 142953  95-97 Barrel sample. A hugely dense wine, pack...
# 51881   Smells sharp and jammy and tastes tart and aci...
# 131667  Voluptuous, with decadently rich flavors of ca...
# 78961   Riper in style than Ara's Composite bottling, ...
# 74060   A massive wine, decadent and splendid, and a w...
# 90313   Clean, brisk and balanced, with good varietal ...
# 121213  Sweet, soft and simple, with fruit stand flavors.
#
#                                               designation  points  price  \
# 117329                            Del-Mar Private Reserve      87   32.0
# 133826                                                NaN      86   45.0
# 7205                                      Austrian Cherry      90   14.0
# 142953                                      Barrel sample      96    NaN
# 51881                                    Fióre Marcheschi      81   24.0
# 131667  À Côté Santa Barbara Highlands Vineyard South ...      92   29.0
# 78961                                            Resolute      86   26.0
# 74060                                      Family Reserve      96  135.0
# 90313                                                 NaN      87   13.0
# 121213                                         Red Shorts      81   12.0
#
#                 province              region_1           region_2  \
# 117329            Oregon     Willamette Valley  Willamette Valley
# 133826           Epanomi                   NaN                NaN
# 7205    Niederösterreich                   NaN                NaN
# 142953          Bordeaux         Saint-Estèphe                NaN
# 51881         California      Alexander Valley             Sonoma
# 131667        California  Santa Barbara County      Central Coast
# 78961        Marlborough                   NaN                NaN
# 74060         California           Napa Valley               Napa
# 90313         California           Napa Valley               Napa
# 121213        California                  Lodi     Central Valley
#
#                          variety                   winery
# 117329                Pinot Noir                Evergreen
# 133826                  Viognier    Domaine Gerovassiliou
# 7205                    Zweigelt                  The Dot
# 142953  Bordeaux-style Red Blend  Château Cos d'Estournel
# 51881                 Sangiovese     Irish Monkey Cellars
# 131667                     Syrah               La Fenêtre
# 78961            Sauvignon Blanc                      Ara
# 74060         Cabernet Sauvignon                    Venge
# 90313                 Chardonnay                    Irony
# 121213                 Red Blend                  Peirano

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df.drop('region_2', axis=1, inplace=True)

# %%
df.sample(10)
# Out:
#              country                                        description  \
# 78647             US  If you like that bite of gooseberry and dry, g...
# 27191             US  Soft and layered, this wine has firmness and d...
# 87033             US  This is a standout in this price range. The we...
# 139761         Italy  This is a gorgeous and very smooth wine that b...
# 8832          France  Jaboulet's Condrieu program takes a huge step ...
# 42188             US  A solid Cabernet, dry and full bodied, that sh...
# 61363   South Africa  With its mélange of Verdelho, Viognier, Grenac...
# 26097             US  Sweet and fizzy, with orange soda and vanilla ...
# 128326            US  Too acidic, even for Petite Sirah, and the aci...
# 103266      Portugal  Soft, with strawberry flavors and only light a...
#
#                         designation  points  price        province  \
# 78647                           NaN      87   18.0      California
# 27191         Van der Kamp Vineyard      91   49.0      California
# 87033                     JV Estate      89   25.0          Oregon
# 139761              Piaggia Riserva      92    NaN         Tuscany
# 8832    Domaine de Grands Amandiers      93  100.0    Rhône Valley
# 42188             Vintner's Reserve      87   20.0      California
# 61363                   Fair Maiden      87   15.0  Coastal Region
# 26097                           NaN      85   13.0      California
# 128326             Jonquil Vineyard      85   35.0      California
# 103266                  Dona Helena      83    NaN         Setubal
#
#                              region_1             variety              winery
# 78647   Happy Canyon of Santa Barbara     Sauvignon Blanc                 3CV
# 27191                 Sonoma Mountain          Pinot Noir              Siduri
# 87033                    Dundee Hills          Pinot Noir             Stoller
# 139761                     Carmignano           Red Blend      Mauro Vannucci
# 8832                         Condrieu            Viognier  Paul Jaboulet Aîné
# 42188           Sonoma-Napa-Mendocino  Cabernet Sauvignon     Kendall-Jackson
# 61363                             NaN         White Blend          Bellingham
# 26097                      California             Moscato              Allure
# 128326                    Napa Valley        Petite Sirah        Hopper Creek
# 103266                            NaN                Rosé  Wines & Winemakers

# %%
predictors = df[['country', 'description', 'designation', 'province', 'region_1', 'variety', 'winery']]

# %%
predictors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150930 entries, 0 to 150929
# Data columns (total 7 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   country      150925 non-null  object
#  1   description  150930 non-null  object
#  2   designation  105195 non-null  object
#  3   province     150925 non-null  object
#  4   region_1     125870 non-null  object
#  5   variety      150930 non-null  object
#  6   winery       150930 non-null  object
# dtypes: object(7)
# memory usage: 8.1+ MB

# %% [markdown]
# ## Missing Data
#
# For the first iteration of this recommender system, I will drop observations with missing values across the board instead of being more selective. This cuts the available data in half. Next iterations could try modelling using fewer features, but more observations.

# %%
predictors.dropna(inplace=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
predictors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 85614 entries, 0 to 150928
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   country      85614 non-null  object
#  1   description  85614 non-null  object
#  2   designation  85614 non-null  object
#  3   province     85614 non-null  object
#  4   region_1     85614 non-null  object
#  5   variety      85614 non-null  object
#  6   winery       85614 non-null  object
# dtypes: object(7)
# memory usage: 5.2+ MB

# %%
predictors = predictors.reset_index()

# %%
predictors.description.duplicated().value_counts()
# Out:
# False    55449
# True     30165
# Name: description, dtype: int64

# %%
predictors.duplicated().value_counts()
# Out:
# False    85614
# dtype: int64

# %%
predictors[(predictors.description.duplicated() == True)]
# Out:
#         index country                                        description  \
# 203       300      US  This standout Rocks District wine brings earth...
# 289       423      US  The aromas on this wine are quite light, conve...
# 290       424   Spain  A mix of smoke and toast blends with fresh, cr...
# 316       480      US  Made from what Californians call the Pommard c...
# 520       810   Italy  Here's a lively Moscato made in a dry style th...
# ...       ...     ...                                                ...
# 85609  150923  France  Rich and toasty, with tiny bubbles. The bouque...
# 85610  150924  France  Really fine for a low-acid vintage, there's an...
# 85611  150926  France  Offers an intriguing nose with ginger, lime an...
# 85612  150927   Italy  This classic example comes from a cru vineyard...
# 85613  150928  France  A perfect salmon shade, with scents of peaches...
#
#                      designation           province                 region_1  \
# 203              The Funk Estate         Washington  Walla Walla Valley (WA)
# 289                      Weinbau         Washington            Wahluke Slope
# 290        Yá Cuvée 23 Brut Rosé          Catalonia                     Cava
# 316    Charles Vineyard Clone O5         California          Anderson Valley
# 520                   Bianco Dry  Sicily & Sardinia                     Noto
# ...                          ...                ...                      ...
# 85609                   Demi-Sec          Champagne                Champagne
# 85610               Diamant Bleu          Champagne                Champagne
# 85611             Cuvée Prestige          Champagne                Champagne
# 85612              Terre di Dora     Southern Italy        Fiano di Avellino
# 85613            Grand Brut Rosé          Champagne                Champagne
#
#                variety                   winery
# 203              Syrah                   Saviah
# 289           Grenache                Sol Stone
# 290    Sparkling Blend                Sumarroca
# 316         Pinot Noir                Foursight
# 520            Moscato                  Planeta
# ...                ...                      ...
# 85609  Champagne Blend                 Jacquart
# 85610  Champagne Blend  Heidsieck & Co Monopole
# 85611  Champagne Blend                H.Germain
# 85612      White Blend                Terredora
# 85613  Champagne Blend                   Gosset
#
# [30165 rows x 8 columns]

# %%
predictors.sample(10)
# Out:
#         index country                                        description  \
# 34767   59571      US  A Cab-based Bordeaux blend with a little Syrah...
# 43743   76158  France  A very fine wine with some bottle age that has...
# 84611  148478      US  This is a tart, racy, exciting wine, showing j...
# 50023   87179      US  Tough in acidity and tannins, this Pinot is no...
# 57077   99499   Italy  Here's a vineyard-designate Riserva distinguis...
# 30858   53115   Italy  The Preda Sarmassa Barolo Riserva offers an in...
# 15963   27173      US  An herbally prolific blend of 46% Cabernet Fra...
# 58986  103000      US  A little too soft and sweet for balance, with ...
# 20916   35587  France  A lean, high acid wine that has a dry edge to ...
# 79430  138738   Italy  Offers measured peach, melon and grass aromas....
#
#                            designation           province  \
# 34767                          Bad Boy         California
# 43743                        Orbe Noir   Southwest France
# 84611                         Big Easy         Washington
# 50023           Olivet Grange Vineyard         California
# 57077      Vigneto Bucerchiale Riserva            Tuscany
# 30858           Preda Sarmassa Riserva           Piedmont
# 15963  Farmer Mickey's Limited Edition         California
# 58986                       HMR Estate         California
# 20916               Bourgogne A. Rodet           Burgundy
# 79430                         Stemmari  Sicily & Sardinia
#
#                    region_1             variety                   winery
# 34767            Yountville           Red Blend                    Rocca
# 43743                Cahors              Malbec  Domaine le Bout du Lieu
# 84611  Columbia Valley (WA)  Cabernet Sauvignon                  Stevens
# 50023  Russian River Valley          Pinot Noir             Inman Family
# 57077        Chianti Rufina          Sangiovese               Selvapiana
# 30858                Barolo            Nebbiolo           Virna Borgogno
# 15963           Paso Robles           Red Blend       Four Sisters Ranch
# 58986           Paso Robles          Chardonnay                 Adelaida
# 20916             Bourgogne          Pinot Noir            Antonin Rodet
# 79430               Sicilia              Grillo            Feudo Arancio

# %% [markdown]
# ## Feature Engineering & Unique Names for Wines

# %%
## Creating a more detailed name for each wine by combining Winery and Designation

predictors['name'] = predictors['winery'] + ', ' + predictors['designation']

# %%
predictors.drop('index', axis=1, inplace=True)

# %%
predictors.sample(10)
# Out:
#          country                                        description  \
# 1921       Italy  Fragrances suggest hay, crushed tomato vine an...
# 44338      Italy  Slightly more subdued in aromatic intensity, t...
# 17199  Argentina  This is an unusual, exotic take on Malbec. The...
# 33027         US  Some high-toned floral highlights liven up the...
# 9957       Italy  Hearty Negroamaro with 15% Malvasia Nera produ...
# 47276         US  Dark and jellied, with raspberry and vanilla f...
# 73804         US  This blend of Zin, Petite Sirah and Mourvèdre ...
# 23983      Italy  This expression of Trebbiano and Chardonnay is...
# 50927         US  If you like your Chardonnay on the fruity side...
# 19470         US  This is the third release of Figgins, a single...
#
#               designation            province                        region_1  \
# 1921          Kirchleiten  Northeastern Italy                      Alto Adige
# 44338            Vignassa            Piedmont  Barbera d'Asti Superiore Nizza
# 17199            Altísimo    Mendoza Province                      Uco Valley
# 33027         Final-Final          Washington            Columbia Valley (WA)
# 9957        Schiaccianoci      Southern Italy                         Salento
# 47276  Grenache Mourvedre          California            Santa Barbara County
# 73804    Phantom Old Vine          California                      California
# 23983         Pergliamici             Tuscany                         Toscana
# 50927  Artisan Collection          California                      California
# 19470              Estate          Washington         Walla Walla Valley (WA)
#
#                         variety             winery  \
# 1921                  Sauvignon      Tiefenbrunner
# 44338                   Barbera  Cascina La Ghersa
# 17199                    Malbec       Ricominciare
# 33027            Cabernet-Syrah             Efeste
# 9957                 Negroamaro       Vigne & Vini
# 47276                      Rosé            Tercero
# 73804                 Red Blend              Bogle
# 23983               White Blend          Casa Sola
# 50927                Chardonnay          HandCraft
# 19470  Bordeaux-style Red Blend            Figgins
#
#                                 name
# 1921      Tiefenbrunner, Kirchleiten
# 44338    Cascina La Ghersa, Vignassa
# 17199         Ricominciare, Altísimo
# 33027            Efeste, Final-Final
# 9957     Vigne & Vini, Schiaccianoci
# 47276    Tercero, Grenache Mourvedre
# 73804        Bogle, Phantom Old Vine
# 23983         Casa Sola, Pergliamici
# 50927  HandCraft, Artisan Collection
# 19470                Figgins, Estate

# %%
## Leaving this in for future ideas

## Creating a UID for each wine by combining all data into one variable

#predictors['uid'] = predictors['winery'] + ', ' + predictors['designation'] + ', ' + predictors['country'] + ', ' + predictors['description'] + ', ' + predictors['province'] + ', ' + predictors['region_1'] + ', ' + predictors['variety']

# %% [markdown]
# ### Removing Duplicate Values

# %%
predictors.drop_duplicates(inplace=True)

# %%
predictors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 55461 entries, 0 to 85141
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   country      55461 non-null  object
#  1   description  55461 non-null  object
#  2   designation  55461 non-null  object
#  3   province     55461 non-null  object
#  4   region_1     55461 non-null  object
#  5   variety      55461 non-null  object
#  6   winery       55461 non-null  object
#  7   name         55461 non-null  object
# dtypes: object(8)
# memory usage: 3.8+ MB

# %%
predictors.country.value_counts()
# Out:
# US           26157
# Italy        10537
# France        9761
# Spain         4317
# Argentina     2428
# Australia     2147
# Canada         114
# Name: country, dtype: int64

# %%
predictors.name.duplicated().value_counts()
# Out:
# False    33549
# True     21912
# Name: name, dtype: int64

# %% [markdown]
# In order for the end user to recieve recommendations, using this model and approach, they need to enter a unique name for a wine they like. With so many duplicates this becomes tricky. For now I will drop duplicated wine values, which significantly reduces the volume of data but solved the uniqueness issue. There is almost certainly a better way around this!

# %%
predictors.drop_duplicates(subset='name', keep='last', inplace=True)

# %%
predictors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 33549 entries, 1 to 85141
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   country      33549 non-null  object
#  1   description  33549 non-null  object
#  2   designation  33549 non-null  object
#  3   province     33549 non-null  object
#  4   region_1     33549 non-null  object
#  5   variety      33549 non-null  object
#  6   winery       33549 non-null  object
#  7   name         33549 non-null  object
# dtypes: object(8)
# memory usage: 2.3+ MB

# %%
predictors.reset_index(inplace=True)

# %%
predictors.drop('index', axis=1, inplace=True)

# %% [markdown]
# ## Vectorizing With Tfidf

# %%
vectors = TfidfVectorizer(min_df = 3,
                         max_features = None,
                         strip_accents = 'unicode',
                         analyzer = 'word',
                         token_pattern = '\w{2,}',
                         ngram_range = (1,3),
                         stop_words = 'english')

# %%
vectors_matrix = vectors.fit_transform(predictors['description'])

# %%
vectors_matrix.shape
# Out:
# (33549, 73445)

# %% [markdown]
# ## Calculating Similarity

# %%
sig_kern = sigmoid_kernel(vectors_matrix, vectors_matrix)

# %%
sig_kern
# Out:
# array([[0.76159987, 0.76159421, 0.76159418, ..., 0.76159416, 0.76159422,
#         0.76159418],
#        [0.76159421, 0.76159987, 0.76159418, ..., 0.76159417, 0.76159417,
#         0.76159417],
#        [0.76159418, 0.76159418, 0.76159987, ..., 0.76159418, 0.76159418,
#         0.76159418],
#        ...,
#        [0.76159416, 0.76159417, 0.76159418, ..., 0.76159987, 0.76159417,
#         0.76159423],
#        [0.76159422, 0.76159417, 0.76159418, ..., 0.76159417, 0.76159987,
#         0.76159419],
#        [0.76159418, 0.76159417, 0.76159418, ..., 0.76159423, 0.76159419,
#         0.76159987]])

# %%
index = pd.Series(predictors.index, index=predictors['name']).drop_duplicates()

# %%
index.to_csv('sig_wines.csv')

# %% [markdown]
# ## The Recommender

# %%
def recommend_wine(name, sig_kern=sig_kern):
    indx = index[name]
    sigmoid_score = list(enumerate(sig_kern[indx]))
    sigmoid_score = sorted(sigmoid_score, key = lambda x:x[1], reverse = True)
    sigmoid_score = sigmoid_score[1:4]
    position = [i[0] for i in sigmoid_score]
    return predictors.iloc[position]

# %%
recommend_wine('Castelli del Grevepesa, Riserva Castelgreve')
# Out:
#          country                                        description  \
# 19711      Italy  Made with Sangiovese, this shows ripe berry an...
# 30485  Argentina  This wine shows molasses and Boston baked bean...
# 22443      Italy  From the Classico zone of Amarone, this shows ...
#
#                  designation          province  \
# 19711    Terra Rossa Riserva           Tuscany
# 30485  Paris Goulart Reserva  Mendoza Province
# 22443            Corte Vaona            Veneto
#
#                                   region_1                        variety  \
# 19711                 Chianti Colli Senesi                     Sangiovese
# 30485                              Mendoza      Malbec-Cabernet Sauvignon
# 22443  Amarone della Valpolicella Classico  Corvina, Rondinella, Molinara
#
#                     winery                                      name
# 19711  Tenuta di Trecciano  Tenuta di Trecciano, Terra Rossa Riserva
# 30485       Bodega Goulart     Bodega Goulart, Paris Goulart Reserva
# 22443               Novaia                       Novaia, Corte Vaona
